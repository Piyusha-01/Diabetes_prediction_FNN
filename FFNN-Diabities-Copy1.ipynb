# %%
import numpy as np
import torch
import torch.nn as nn
import pandas as pd
from sklearn.preprocessing import StandardScaler
from torch.utils.data import Dataset
from torch.utils.data import DataLoader

# %%
# Load the dataset using Pandas
data = pd.read_csv('diabetes.csv')
data
# Out:
#      Number of times pregnant  Plasma glucose concentration  \
# 0                           6                           148
# 1                           1                            85
# 2                           8                           183
# 3                           1                            89
# 4                           0                           137
# ..                        ...                           ...
# 763                        10                           101
# 764                         2                           122
# 765                         5                           121
# 766                         1                           126
# 767                         1                            93
#
#      Diastolic blood pressure  Triceps skin fold thickness  \
# 0                          72                           35
# 1                          66                           29
# 2                          64                            0
# 3                          66                           23
# 4                          40                           35
# ..                        ...                          ...
# 763                        76                           48
# 764                        70                           27
# 765                        72                           23
# 766                        60                            0
# 767                        70                           31
#
#      2-Hour serum insulin  Body mass index  Age     Class
# 0                       0             33.6   50  positive
# 1                       0             26.6   31  negative
# 2                       0             23.3   32  positive
# 3                      94             28.1   21  negative
# 4                     168             43.1   33  positive
# ..                    ...              ...  ...       ...
# 763                   180             32.9   63  negative
# 764                     0             36.8   27  negative
# 765                   112             26.2   30  negative
# 766                     0             30.1   47  positive
# 767                     0             30.4   23  negative
#
# [768 rows x 8 columns]

# %%
# For x: Extract out the dataset from all the rows (all samples) and all columns except last column (all features). 
# For y: Extract out the last column (which is the label)
# Convert both to numpy using the .values method
x = data.iloc[:,0:-1].values
y_string= list(data.iloc[:,-1])

# %%
# Lets have a look some samples from our data
print(x[:3])
print(y_string[:3])
# Out:
# [[  6.  148.   72.   35.    0.   33.6  50. ]
#  [  1.   85.   66.   29.    0.   26.6  31. ]
#  [  8.  183.   64.    0.    0.   23.3  32. ]]
# ['positive', 'negative', 'positive']

# %%
# Our neural network only understand numbers! So convert the string to labels
y_int = []
for string in y_string:
    if string == 'positive':
        y_int.append(1)
    else:
        y_int.append(0)

# %%
# Now convert to an array
y = np.array(y_int, dtype = 'float64')

# %%
# Feature Normalization. All features should have the same range of values (-1,1)
sc = StandardScaler()
x = sc.fit_transform(x)

# %%
# Now we convert the arrays to PyTorch tensors
x = torch.tensor(x)
# We add an extra dimension to convert this array to 2D
y = torch.tensor(y).unsqueeze(1)

# %%
#lets watch shape of it
print(x.shape)
print(y.shape)
# Out:
# torch.Size([768, 7])
# torch.Size([768, 1])

# %%
class Dataset(Dataset):

    def __init__(self,x,y):
        self.x = x
        self.y = y
        
    def __getitem__(self,index):
        # Get one item from the dataset
        return self.x[index], self.y[index]
    
    def __len__(self):
        return len(self.x)

# %%
dataset = Dataset(x,y)

# %%
len(dataset)
# Out:
# 768

# %%
# Load the data to your dataloader for batch processing and shuffling
train_loader = torch.utils.data.DataLoader(dataset=dataset,
                                           batch_size=32,
                                           shuffle=True)
train_loader

# %%
# Let's have a look at the data loader
print("There is {} batches in the dataset".format(len(train_loader)))
for (x,y) in train_loader:
    print("For one iteration (batch), there is:")
    print("Data:    {}".format(x.shape))
    print("Labels:  {}".format(y.shape))
    break
# Out:
# There is 24 batches in the dataset
# For one iteration (batch), there is:
# Data:    torch.Size([32, 7])
# Labels:  torch.Size([32, 1])

# %%
# Now let's build the above network
class Model(nn.Module):
    def __init__(self, input_features , output_features):
        super(Model, self).__init__()
        self.fc1 = nn.Linear(input_features, 5)
        self.fc2 = nn.Linear(5, 4)
        self.fc3 = nn.Linear(4, 3)
        self.fc4 = nn.Linear(3, 1)
        self.sigmoid = nn.Sigmoid()
        self.tanh = nn.Tanh()

    def forward(self, x):
        out = self.fc1(x)
        out = self.tanh(out)
        out = self.fc2(out)
        out = self.tanh(out)
        out = self.fc3(out)
        out = self.tanh(out)
        out = self.fc4(out)
        out = self.sigmoid(out)
        return out

# %%
# Create the network (an object of the Net class)
net = Model(7,1)
#In Binary Cross Entropy: the input and output should have the same shape 
#size_average = True --> the losses are averaged over observations for each minibatch
criterion = torch.nn.BCELoss(size_average=True)   
# We will use SGD with momentum with a learning rate of 0.1
optimizer = torch.optim.SGD(net.parameters(), lr=0.1, momentum=0.9)

# %%
# Train the network 
num_epochs = 200
for epoch in range(num_epochs):
    for inputs,labels in train_loader:
        inputs = inputs.float()
        labels = labels.float()
        # Feed Forward
        output = net(inputs)
        # Loss Calculation
        loss = criterion(output, labels)
        # Clear the gradient buffer (we don't want to accumulate gradients)
        optimizer.zero_grad()
        # Backpropagation 
        loss.backward()
        # Weight Update: w <-- w - lr * gradient
        optimizer.step()
        
    #Accuracy
    # Since we are using a sigmoid, we will need to perform some thresholding
    output = (output>0.5).float()
    # Accuracy: (output == labels).float().sum() / output.shape[0]
    accuracy = (output == labels).float().mean()
    # Print statistics 
    print("Epoch {}/{}, Loss: {:.5f}, Accuracy: {:.5f}".format(epoch+1,num_epochs, loss, accuracy))
# Out:
# Epoch 1/200, Loss: 0.47433, Accuracy: 0.68750
# Epoch 2/200, Loss: 0.47199, Accuracy: 0.65625
# Epoch 3/200, Loss: 0.41792, Accuracy: 0.81250
# Epoch 4/200, Loss: 0.26280, Accuracy: 0.84375
# Epoch 5/200, Loss: 0.42737, Accuracy: 0.71875
# Epoch 6/200, Loss: 0.28289, Accuracy: 0.87500
# Epoch 7/200, Loss: 0.27447, Accuracy: 0.84375
# Epoch 8/200, Loss: 0.45021, Accuracy: 0.78125
# Epoch 9/200, Loss: 0.52810, Accuracy: 0.65625
# Epoch 10/200, Loss: 0.35457, Accuracy: 0.81250
# Epoch 11/200, Loss: 0.33479, Accuracy: 0.87500
# Epoch 12/200, Loss: 0.30650, Accuracy: 0.87500
# Epoch 13/200, Loss: 0.47745, Accuracy: 0.75000
# Epoch 14/200, Loss: 0.34004, Accuracy: 0.87500
# Epoch 15/200, Loss: 0.37817, Accuracy: 0.84375
# Epoch 16/200, Loss: 0.39060, Accuracy: 0.78125
# Epoch 17/200, Loss: 0.26434, Accuracy: 0.87500
# Epoch 18/200, Loss: 0.57882, Accuracy: 0.75000
# Epoch 19/200, Loss: 0.36213, Accuracy: 0.81250
# Epoch 20/200, Loss: 0.39697, Accuracy: 0.78125
# Epoch 21/200, Loss: 0.52269, Accuracy: 0.68750
# Epoch 22/200, Loss: 0.44602, Accuracy: 0.81250
# Epoch 23/200, Loss: 0.39682, Accuracy: 0.78125
# Epoch 24/200, Loss: 0.42012, Accuracy: 0.78125
# Epoch 25/200, Loss: 0.60665, Accuracy: 0.71875
# Epoch 26/200, Loss: 0.36367, Accuracy: 0.84375
# Epoch 27/200, Loss: 0.37745, Accuracy: 0.75000
# Epoch 28/200, Loss: 0.29235, Accuracy: 0.93750
# Epoch 29/200, Loss: 0.33177, Accuracy: 0.81250
# Epoch 30/200, Loss: 0.30463, Accuracy: 0.87500
# Epoch 31/200, Loss: 0.29948, Accuracy: 0.87500
# Epoch 32/200, Loss: 0.33910, Accuracy: 0.81250
# Epoch 33/200, Loss: 0.39105, Accuracy: 0.81250
# Epoch 34/200, Loss: 0.17978, Accuracy: 1.00000
# Epoch 35/200, Loss: 0.24510, Accuracy: 0.93750
# Epoch 36/200, Loss: 0.36011, Accuracy: 0.78125
# Epoch 37/200, Loss: 0.39204, Accuracy: 0.71875
# Epoch 38/200, Loss: 0.46036, Accuracy: 0.78125
# Epoch 39/200, Loss: 0.39787, Accuracy: 0.78125
# Epoch 40/200, Loss: 0.65517, Accuracy: 0.75000
# Epoch 41/200, Loss: 0.27739, Accuracy: 0.90625
# Epoch 42/200, Loss: 0.42259, Accuracy: 0.75000
# Epoch 43/200, Loss: 0.54176, Accuracy: 0.62500
# Epoch 44/200, Loss: 0.21157, Accuracy: 0.90625
# Epoch 45/200, Loss: 0.28805, Accuracy: 0.84375
# Epoch 46/200, Loss: 0.34531, Accuracy: 0.87500
# Epoch 47/200, Loss: 0.47788, Accuracy: 0.78125
# Epoch 48/200, Loss: 0.26216, Accuracy: 0.90625
# Epoch 49/200, Loss: 0.29237, Accuracy: 0.87500
# Epoch 50/200, Loss: 0.34481, Accuracy: 0.81250
# Epoch 51/200, Loss: 0.38931, Accuracy: 0.81250
# Epoch 52/200, Loss: 0.33185, Accuracy: 0.78125
# Epoch 53/200, Loss: 0.32030, Accuracy: 0.75000
# Epoch 54/200, Loss: 0.45749, Accuracy: 0.84375
# Epoch 55/200, Loss: 0.51986, Accuracy: 0.71875
# Epoch 56/200, Loss: 0.36855, Accuracy: 0.84375
# Epoch 57/200, Loss: 0.37430, Accuracy: 0.81250
# Epoch 58/200, Loss: 0.56674, Accuracy: 0.71875
# Epoch 59/200, Loss: 0.42740, Accuracy: 0.71875
# Epoch 60/200, Loss: 0.22457, Accuracy: 0.87500
# Epoch 61/200, Loss: 0.27851, Accuracy: 0.87500
# Epoch 62/200, Loss: 0.38644, Accuracy: 0.71875
# Epoch 63/200, Loss: 0.35051, Accuracy: 0.84375
# Epoch 64/200, Loss: 0.49087, Accuracy: 0.71875
# Epoch 65/200, Loss: 0.30862, Accuracy: 0.81250
# Epoch 66/200, Loss: 0.29230, Accuracy: 0.84375
# Epoch 67/200, Loss: 0.26195, Accuracy: 0.81250
# Epoch 68/200, Loss: 0.37759, Accuracy: 0.87500
# Epoch 69/200, Loss: 0.40451, Accuracy: 0.84375
# Epoch 70/200, Loss: 0.31718, Accuracy: 0.87500
# Epoch 71/200, Loss: 0.23200, Accuracy: 0.87500
# Epoch 72/200, Loss: 0.40891, Accuracy: 0.90625
# Epoch 73/200, Loss: 0.40840, Accuracy: 0.71875
# Epoch 74/200, Loss: 0.20936, Accuracy: 0.90625
# Epoch 75/200, Loss: 0.40519, Accuracy: 0.75000
# Epoch 76/200, Loss: 0.35162, Accuracy: 0.81250
# Epoch 77/200, Loss: 0.44078, Accuracy: 0.78125
# Epoch 78/200, Loss: 0.36116, Accuracy: 0.81250
# Epoch 79/200, Loss: 0.33786, Accuracy: 0.81250
# Epoch 80/200, Loss: 0.25667, Accuracy: 0.78125
# Epoch 81/200, Loss: 0.29049, Accuracy: 0.84375
# Epoch 82/200, Loss: 0.40421, Accuracy: 0.81250
# Epoch 83/200, Loss: 0.43543, Accuracy: 0.78125
# Epoch 84/200, Loss: 0.33119, Accuracy: 0.75000
# Epoch 85/200, Loss: 0.46554, Accuracy: 0.68750
# Epoch 86/200, Loss: 0.46881, Accuracy: 0.78125
# Epoch 87/200, Loss: 0.48928, Accuracy: 0.78125
# Epoch 88/200, Loss: 0.46383, Accuracy: 0.81250
# Epoch 89/200, Loss: 0.41134, Accuracy: 0.81250
# Epoch 90/200, Loss: 0.32667, Accuracy: 0.87500
# Epoch 91/200, Loss: 0.30113, Accuracy: 0.84375
# Epoch 92/200, Loss: 0.25280, Accuracy: 0.90625
# Epoch 93/200, Loss: 0.54433, Accuracy: 0.71875
# Epoch 94/200, Loss: 0.47956, Accuracy: 0.75000
# Epoch 95/200, Loss: 0.27810, Accuracy: 0.90625
# Epoch 96/200, Loss: 0.44973, Accuracy: 0.75000
# Epoch 97/200, Loss: 0.46441, Accuracy: 0.68750
# Epoch 98/200, Loss: 0.40550, Accuracy: 0.78125
# Epoch 99/200, Loss: 0.37581, Accuracy: 0.81250
# Epoch 100/200, Loss: 0.19875, Accuracy: 0.96875
# Epoch 101/200, Loss: 0.44251, Accuracy: 0.71875
# Epoch 102/200, Loss: 0.29559, Accuracy: 0.84375
# Epoch 103/200, Loss: 0.26448, Accuracy: 0.90625
# Epoch 104/200, Loss: 0.47551, Accuracy: 0.75000
# Epoch 105/200, Loss: 0.40424, Accuracy: 0.78125
# Epoch 106/200, Loss: 0.36383, Accuracy: 0.81250
# Epoch 107/200, Loss: 0.34611, Accuracy: 0.87500
# Epoch 108/200, Loss: 0.38218, Accuracy: 0.81250
# Epoch 109/200, Loss: 0.42729, Accuracy: 0.81250
# Epoch 110/200, Loss: 0.64078, Accuracy: 0.68750
# Epoch 111/200, Loss: 0.41742, Accuracy: 0.71875
# Epoch 112/200, Loss: 0.22776, Accuracy: 0.90625
# Epoch 113/200, Loss: 0.35237, Accuracy: 0.81250
# Epoch 114/200, Loss: 0.39828, Accuracy: 0.78125
# Epoch 115/200, Loss: 0.31378, Accuracy: 0.84375
# Epoch 116/200, Loss: 0.33612, Accuracy: 0.84375
# Epoch 117/200, Loss: 0.50701, Accuracy: 0.78125
# Epoch 118/200, Loss: 0.42760, Accuracy: 0.81250
# Epoch 119/200, Loss: 0.44249, Accuracy: 0.68750
# Epoch 120/200, Loss: 0.32914, Accuracy: 0.84375
# Epoch 121/200, Loss: 0.30600, Accuracy: 0.87500
# Epoch 122/200, Loss: 0.23631, Accuracy: 0.87500
# Epoch 123/200, Loss: 0.32857, Accuracy: 0.81250
# Epoch 124/200, Loss: 0.33339, Accuracy: 0.87500
# Epoch 125/200, Loss: 0.37501, Accuracy: 0.81250
# Epoch 126/200, Loss: 0.32547, Accuracy: 0.93750
# Epoch 127/200, Loss: 0.31799, Accuracy: 0.87500
# Epoch 128/200, Loss: 0.29159, Accuracy: 0.81250
# Epoch 129/200, Loss: 0.37094, Accuracy: 0.81250
# Epoch 130/200, Loss: 0.37175, Accuracy: 0.81250
# Epoch 131/200, Loss: 0.32187, Accuracy: 0.87500
# Epoch 132/200, Loss: 0.27177, Accuracy: 0.96875
# Epoch 133/200, Loss: 0.24359, Accuracy: 0.87500
# Epoch 134/200, Loss: 0.55406, Accuracy: 0.62500
# Epoch 135/200, Loss: 0.28281, Accuracy: 0.87500
# Epoch 136/200, Loss: 0.18143, Accuracy: 0.96875
# Epoch 137/200, Loss: 0.42513, Accuracy: 0.78125
# Epoch 138/200, Loss: 0.35100, Accuracy: 0.84375
# Epoch 139/200, Loss: 0.39514, Accuracy: 0.84375
# Epoch 140/200, Loss: 0.26386, Accuracy: 0.90625
# Epoch 141/200, Loss: 0.29605, Accuracy: 0.87500
# Epoch 142/200, Loss: 0.37231, Accuracy: 0.84375
# Epoch 143/200, Loss: 0.39490, Accuracy: 0.84375
# Epoch 144/200, Loss: 0.37653, Accuracy: 0.78125
# Epoch 145/200, Loss: 0.36871, Accuracy: 0.78125
# Epoch 146/200, Loss: 0.46856, Accuracy: 0.75000
# Epoch 147/200, Loss: 0.26234, Accuracy: 0.90625
# Epoch 148/200, Loss: 0.43685, Accuracy: 0.78125
# Epoch 149/200, Loss: 0.41010, Accuracy: 0.84375
# Epoch 150/200, Loss: 0.43189, Accuracy: 0.78125
# Epoch 151/200, Loss: 0.43857, Accuracy: 0.84375
# Epoch 152/200, Loss: 0.40297, Accuracy: 0.84375
# Epoch 153/200, Loss: 0.19463, Accuracy: 0.93750
# Epoch 154/200, Loss: 0.31726, Accuracy: 0.84375
# Epoch 155/200, Loss: 0.33366, Accuracy: 0.84375
# Epoch 156/200, Loss: 0.37092, Accuracy: 0.81250
# Epoch 157/200, Loss: 0.42178, Accuracy: 0.84375
# Epoch 158/200, Loss: 0.64086, Accuracy: 0.62500
# Epoch 159/200, Loss: 0.28551, Accuracy: 0.84375
# Epoch 160/200, Loss: 0.38573, Accuracy: 0.78125
# Epoch 161/200, Loss: 0.40350, Accuracy: 0.78125
# Epoch 162/200, Loss: 0.31195, Accuracy: 0.81250
# Epoch 163/200, Loss: 0.32466, Accuracy: 0.84375
# Epoch 164/200, Loss: 0.17377, Accuracy: 0.93750
# Epoch 165/200, Loss: 0.33629, Accuracy: 0.81250
# Epoch 166/200, Loss: 0.53150, Accuracy: 0.78125
# Epoch 167/200, Loss: 0.27945, Accuracy: 0.84375
# Epoch 168/200, Loss: 0.38802, Accuracy: 0.75000
# Epoch 169/200, Loss: 0.45761, Accuracy: 0.75000
# Epoch 170/200, Loss: 0.34014, Accuracy: 0.81250
# Epoch 171/200, Loss: 0.40243, Accuracy: 0.78125
# Epoch 172/200, Loss: 0.44624, Accuracy: 0.81250
# Epoch 173/200, Loss: 0.39097, Accuracy: 0.81250
# Epoch 174/200, Loss: 0.36491, Accuracy: 0.84375
# Epoch 175/200, Loss: 0.33519, Accuracy: 0.84375
# Epoch 176/200, Loss: 0.47846, Accuracy: 0.75000
# Epoch 177/200, Loss: 0.40866, Accuracy: 0.84375
# Epoch 178/200, Loss: 0.48812, Accuracy: 0.78125
# Epoch 179/200, Loss: 0.34045, Accuracy: 0.81250
# Epoch 180/200, Loss: 0.35518, Accuracy: 0.87500
# Epoch 181/200, Loss: 0.42491, Accuracy: 0.84375
# Epoch 182/200, Loss: 0.44241, Accuracy: 0.84375
# Epoch 183/200, Loss: 0.38357, Accuracy: 0.81250
# Epoch 184/200, Loss: 0.57944, Accuracy: 0.75000
# Epoch 185/200, Loss: 0.38926, Accuracy: 0.81250
# Epoch 186/200, Loss: 0.40576, Accuracy: 0.81250
# Epoch 187/200, Loss: 0.30477, Accuracy: 0.87500
# Epoch 188/200, Loss: 0.45690, Accuracy: 0.87500
# Epoch 189/200, Loss: 0.20368, Accuracy: 0.84375
# Epoch 190/200, Loss: 0.34483, Accuracy: 0.81250
# Epoch 191/200, Loss: 0.49055, Accuracy: 0.84375
# Epoch 192/200, Loss: 0.39685, Accuracy: 0.68750
# Epoch 193/200, Loss: 0.26727, Accuracy: 0.90625
# Epoch 194/200, Loss: 0.25368, Accuracy: 0.90625
# Epoch 195/200, Loss: 0.35184, Accuracy: 0.78125
# Epoch 196/200, Loss: 0.29172, Accuracy: 0.93750
# Epoch 197/200, Loss: 0.39601, Accuracy: 0.84375
# Epoch 198/200, Loss: 0.52535, Accuracy: 0.75000
# Epoch 199/200, Loss: 0.48714, Accuracy: 0.81250
# Epoch 200/200, Loss: 0.48400, Accuracy: 0.68750
